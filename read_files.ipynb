# %%
# %sql
create table orders 
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
as
select * from read_files("/Volumes/workspace/revive/revive_vol/Orders.csv")

# %%
# %sql
select * from orders

# %%
# %sql

desc history orders
