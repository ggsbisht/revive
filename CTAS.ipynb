# %%
# %sql
create table ctas_test as 
select * from read_files('/Volumes/workspace/revive/revive_vol/orders1.csv',format=>'csv')

# %%
# %sql
select * from ctas_test

# %%
# %sql
desc extended ctas_test

# %%
# %sql
create table ctas_test_1 as 
select * from read_files('/Volumes/workspace/revive/revive_vol/orders1.csv',format=>'csv',
schema=>'id bigint,name string,item string,qty int,price double,_rescued_data string',header=>'true',mode=>'PEMISSIVE',
columnNameOfCorruptRecord=>'_rescued_data'

)

# %%
# %sql
select * from ctas_test_1
