# %%
# %sql
drop table if exists orders;
-- create table orders;

# %%
# %sql
ALTER TABLE orders
SET TBLPROPERTIES ('delta.enableTypeWidening' = 'true');

# %%
# %sql
copy into orders  from "/Volumes/workspace/revive/revive_vol/orders3.csv" fileformat=csv
format_options("header"="true","delimiter"=',',"mergeSchema"="true",'inferSchema'='true')
copy_options("mergeSchema"="true")

# %%
# %sql
select * from orders

# %%
# %sql
desc formatted orders

# %%
# %sql
desc history orders

# %%
# %sql
create table orders(
  order_id int,
  name string,
  item string,
  qty int,
  price double
)
using delta

# %%
# %sql
copy into orders from (
select id,name,item,qty,price from csv.`/Volumes/workspace/revive/revive_vol/orders1.csv` ) fileformat=csv
format_options("header"="true")

# %%
# %sql
select * from csv.`/Volumes/workspace/revive/revive_vol/orders1.csv`
