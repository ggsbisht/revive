# %%
from pyspark.sql.functions import lit

df = spark.table("ingest_schema.customer_clean")

customer_enrich = df.withColumn("country", lit("USA"))

customer_enrich.write.mode("overwrite").saveAsTable("ingest_schema.customer_enrich")
