# %%
def generic_func(func):
    def wrapper():
        print("before execution")
        func()
        print("after execution")
    return wrapper

# %%
@generic_func
def hello():
    print("hello")

# %%
hello()
