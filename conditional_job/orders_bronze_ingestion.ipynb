# %%
# %sql
-- Create table
CREATE OR REPLACE TABLE bronze.orders (
    order_id INT,
    customer_name STRING,
    order_date DATE,
    amount DOUBLE
);

-- Insert sample data (with duplicates)
INSERT INTO bronze.orders VALUES
(101, 'Alice', '2024-01-01', 250.0),
(102, 'Bob', '2024-01-02', 300.0),
(103, 'Charlie', '2024-01-03', 150.0),
(101, 'Alice', '2024-01-04', 275.0),   -- duplicate order_id
(104, 'David', '2024-01-05', 400.0),
(102, 'Bob', '2024-01-06', 320.0),     -- duplicate order_id
(105, 'Eve', '2024-01-07', 500.0);
